# %%
import pandas as pd
keywords_df = pd.read_csv("other/text/keywords.csv")
keywords = keywords_df['keyword'].tolist()

# %%
keywords

# %%
import asyncio
import sys

# This MUST be the first asyncio call in the notebook
if sys.platform == 'win32':
    asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())

import nest_asyncio
nest_asyncio.apply()

print("Loop policy fixed. Now try running your Playwright code.")

# %%
from app import job_sourcing_pipeline

job_experience_threshold_years = 4.5
minimum_yearly_salary = 96000
resume_path = "other/text/resume.docx"
job_sourcing_pipeline(keywords, minimum_yearly_salary, job_experience_threshold_years, resume_path)
