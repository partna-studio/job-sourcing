# %%
from digistudio.processing.upload import load_collection

cjs = categorized_jobs = load_collection("jobs-display")
display = cjs.iloc[1].to_dict()

# %%
from other.text.transform_jobs import transform_jobs

jobs = transform_jobs(display)

# %%
jobs.keys()
# Out:
# Index(['Compatibility', 'position', 'company', 'location', 'date', 'salary',
#        'jobUrl', 'companyLogo', 'agoTime', 'datePosted', 'employmentTitle',
#        'employmentType', 'description', 'validThrough', 'hiringOrganization',
#        'industry', 'addressCountry', 'addressLocality', 'skills',
#        'credentialCategory', 'monthsOfExperience', 'currency', 'minValue',
#        'maxValue', 'unitText', 'score', 'rationale'],
#       dtype='str')
